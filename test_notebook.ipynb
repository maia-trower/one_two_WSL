# %%
import pandas as pd
from statsbombpy import sb
from mplsoccer import Pitch
import numpy as np
import matplotlib.pyplot as plt

# %%
sb.competitions()
# Out:
#     competition_id  season_id              country_name
# 0               16          4                    Europe  \
# 1               16          1                    Europe
# 2               16          2                    Europe
# 3               16         27                    Europe
# 4               16         26                    Europe
# 5               16         25                    Europe
# 6               16         24                    Europe
# 7               16         23                    Europe
# 8               16         22                    Europe
# 9               16         21                    Europe
# 10              16         41                    Europe
# 11              16         39                    Europe
# 12              16         37                    Europe
# 13              16         44                    Europe
# 14              16         76                    Europe
# 15              37         90                   England
# 16              37         42                   England
# 17              37          4                   England
# 18              43        106             International
# 19              43          3             International
# 20            1238        108                     India
# 21              11         90                     Spain
# 22              11         42                     Spain
# 23              11          4                     Spain
# 24              11          1                     Spain
# 25              11          2                     Spain
# 26              11         27                     Spain
# 27              11         26                     Spain
# 28              11         25                     Spain
# 29              11         24                     Spain
# 30              11         23                     Spain
# 31              11         22                     Spain
# 32              11         21                     Spain
# 33              11         41                     Spain
# 34              11         40                     Spain
# 35              11         39                     Spain
# 36              11         38                     Spain
# 37              11         37                     Spain
# 38              49          3  United States of America
# 39               2         44                   England
# 40              55         43                    Europe
# 41              53        106                    Europe
# 42              72         30             International
#
#            competition_name competition_gender  competition_youth
# 0          Champions League               male              False  \
# 1          Champions League               male              False
# 2          Champions League               male              False
# 3          Champions League               male              False
# 4          Champions League               male              False
# 5          Champions League               male              False
# 6          Champions League               male              False
# 7          Champions League               male              False
# 8          Champions League               male              False
# 9          Champions League               male              False
# 10         Champions League               male              False
# 11         Champions League               male              False
# 12         Champions League               male              False
# 13         Champions League               male              False
# 14         Champions League               male              False
# 15  FA Women's Super League             female              False
# 16  FA Women's Super League             female              False
# 17  FA Women's Super League             female              False
# 18           FIFA World Cup               male              False
# 19           FIFA World Cup               male              False
# 20      Indian Super league               male              False
# 21                  La Liga               male              False
# 22                  La Liga               male              False
# 23                  La Liga               male              False
# 24                  La Liga               male              False
# 25                  La Liga               male              False
# 26                  La Liga               male              False
# 27                  La Liga               male              False
# 28                  La Liga               male              False
# 29                  La Liga               male              False
# 30                  La Liga               male              False
# 31                  La Liga               male              False
# 32                  La Liga               male              False
# 33                  La Liga               male              False
# 34                  La Liga               male              False
# 35                  La Liga               male              False
# 36                  La Liga               male              False
# 37                  La Liga               male              False
# 38                     NWSL             female              False
# 39           Premier League               male              False
# 40                UEFA Euro               male              False
# 41        UEFA Women's Euro             female              False
# 42        Women's World Cup             female              False
#
#     competition_international season_name               match_updated
# 0                       False   2018/2019  2023-03-07T12:20:48.118250  \
# 1                       False   2017/2018  2021-08-27T11:26:39.802832
# 2                       False   2016/2017  2021-08-27T11:26:39.802832
# 3                       False   2015/2016  2021-08-27T11:26:39.802832
# 4                       False   2014/2015  2021-08-27T11:26:39.802832
# 5                       False   2013/2014  2021-08-27T11:26:39.802832
# 6                       False   2012/2013  2021-08-27T11:26:39.802832
# 7                       False   2011/2012  2021-08-27T11:26:39.802832
# 11                         Irene Fuhrmann        1.1.0                     2
# 12                          Ives Serneels        1.1.0                     2
# 13               Corinne Catherine Diacre        1.1.0                     2
# 14                            Jorge Vilda        1.1.0                     2
# 15               Martina Voss-Tecklenburg        1.1.0                     2
# 16                            Jorge Vilda        1.1.0                     2
# 17                           Anna Signeul        1.1.0                     2
# 18                       Lars Søndergaard        1.1.0                     2
# 19  Francisco Miguel Conceição Roque Neto        1.1.0                     2
# 20                         Martin Sjögren        1.1.0                     2
# 21                 Thorsteinn Halldórsson        1.1.0                     2
# 22                          Ives Serneels        1.1.0                     2
# 23  Francisco Miguel Conceição Roque Neto        1.1.0                     2
# 24             Mark Richard David Parsons        1.1.0                     2
# 25                         Martin Sjögren        1.1.0                     2
# 26                 Thorsteinn Halldórsson        1.1.0                     2
# 27                           Kenny Shiels        1.1.0                     2
# 28                          Ives Serneels        1.1.0                     2
# 29                           Anna Signeul        1.1.0                     2
# 30                         Irene Fuhrmann        1.1.0                     2
#
#    xy_fidelity_version
# 0                    2
# 1                    2
# 2                    2
# 3                    2
# 4                    2
# 5                    2
# 6                    2
# 7                    2
# 8                    2
# 9                    2
# 10                   2
# 11                   2
# 12                   2
# 13                   2
# 14                   2
# 15                   2
# 16                   2
# 17                   2
# 18                   2
# 19                   2
# 20                   2
# 21                   2
# 22                   2
# 23                   2
# 24                   2
# 25                   2
# 26                   2
# 27                   2
# 28                   2
# 29                   2
# 30                   2
#
# [31 rows x 22 columns]

# %%
# final
MATCH_ID = 3847567

# %%
final_events = sb.events(match_id=MATCH_ID)

#add 360 data here ...

final_360 = pd.read_json(f"/home/s2113337/Documents/GitHub/open-data/data/three-sixty/{MATCH_ID}.json")

final_df = pd.merge(left=final_events, right=final_360, left_on='id', right_on='event_uuid', how='left')

# %%
final_df
# Out:
#      50_50 bad_behaviour_card ball_receipt_outcome ball_recovery_offensive
# 0      NaN                NaN                  NaN                     NaN  \
# 1      NaN                NaN                  NaN                     NaN
# 2      NaN                NaN                  NaN                     NaN
# 3      NaN                NaN                  NaN                     NaN
# 4      NaN                NaN                  NaN                     NaN
# ...    ...                ...                  ...                     ...
# 3694   NaN                NaN                  NaN                     NaN
# 3695   NaN                NaN                  NaN                     NaN
# 3696   NaN                NaN                  NaN                     NaN
# 3697   NaN                NaN                  NaN                     NaN
# 3698   NaN        Yellow Card                  NaN                     NaN
#
#      ball_recovery_recovery_failure block_deflection carry_end_location
# 0                               NaN              NaN                NaN  \
# 1                               NaN              NaN                NaN
# 2                               NaN              NaN                NaN
# 3                               NaN              NaN                NaN
# 4                               NaN              NaN                NaN
# ...                             ...              ...                ...
# 3694                            NaN              NaN                NaN
# 3695                            NaN              NaN                NaN
# 3696                            NaN              NaN                NaN
# 3697                            NaN              NaN                NaN
# 3698                            NaN              NaN                NaN
#
#      clearance_aerial_won clearance_body_part clearance_head  ...
# 0                     NaN                 NaN            NaN  ...  \
# 1                     NaN                 NaN            NaN  ...
# 2                     NaN                 NaN            NaN  ...
# 3                     NaN                 NaN            NaN  ...
# 4                     NaN                 NaN            NaN  ...
# ...                   ...                 ...            ...  ...
# 3694                  NaN                 NaN            NaN  ...
# 3695                  NaN                 NaN            NaN  ...
# 3696                  NaN                 NaN            NaN  ...
# 3697                  NaN                 NaN            NaN  ...
# 3698                  NaN                 NaN            NaN  ...
#
#      substitution_replacement
# 0                         NaN  \
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 3694                      NaN
# 3695                      NaN
# 3696                      NaN
# 3697                      NaN
# 3698                      NaN
#
#                                                 tactics             team
# 0     {'formation': 4231, 'lineup': [{'player': {'id...  England Women's  \
# 1     {'formation': 433, 'lineup': [{'player': {'id'...  Germany Women's
# 2                                                   NaN  Germany Women's
# 3                                                   NaN  England Women's
# 4                                                   NaN  England Women's
# ...                                                 ...              ...
# 3694  {'formation': 3421, 'lineup': [{'player': {'id...  Germany Women's
# 3695                                                NaN  England Women's
# 3696                                                NaN  England Women's
# 3697                                                NaN  England Women's
# 3698                                                NaN  England Women's
#
#      team_id     timestamp            type under_pressure
# 0        865  00:00:00.000     Starting XI            NaN  \
# 1        857  00:00:00.000     Starting XI            NaN
# 2        857  00:00:00.000      Half Start            NaN
# 3        865  00:00:00.000      Half Start            NaN
# 4        865  00:00:00.000      Half Start            NaN
# ...      ...           ...             ...            ...
# 3694     857  00:09:26.403  Tactical Shift            NaN
# 3695     865  00:15:46.021      Player Off            NaN
# 3696     865  00:17:54.912       Player On            NaN
# 3697     865  00:32:55.824           Error            NaN
# 3698     865  00:06:14.911   Bad Behaviour            NaN
#
#                                 event_uuid
# 0                                      NaN  \
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 3694                                   NaN
# 3695                                   NaN
# 3696                                   NaN
# 3697  8caa11b5-7e3d-4186-9955-5f169e298f29
# 3698                                   NaN
#
#                                            visible_area
# 0                                                   NaN  \
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3694                                                NaN
# 3695                                                NaN
# 3696                                                NaN
# 3697  [31.2259092863042, 72.9532484031392, 21.235095...
# 3698                                                NaN
#
#                                            freeze_frame
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3694                                                NaN
# 3695                                                NaN
# 3696                                                NaN
# 3697  [{'teammate': True, 'actor': False, 'keeper': ...
# 3698                                                NaN
#
# [3699 rows x 97 columns]

# %%
# get all events related to passes ? only use those with a recorded recipient
passes_df = final_df.dropna(subset=["pass_recipient"])

# %%
print(f"number of passes with recorded recipient: {final_df.pass_recipient.count()}")

passes_df
# Out:
# number of passes with recorded recipient: 803
#      50_50 bad_behaviour_card ball_receipt_outcome ball_recovery_offensive
# 10     NaN                NaN                  NaN                     NaN  \
# 11     NaN                NaN                  NaN                     NaN
# 12     NaN                NaN                  NaN                     NaN
# 13     NaN                NaN                  NaN                     NaN
# 14     NaN                NaN                  NaN                     NaN
# ...    ...                ...                  ...                     ...
# 1067   NaN                NaN                  NaN                     NaN
# 1068   NaN                NaN                  NaN                     NaN
# 1069   NaN                NaN                  NaN                     NaN
# 1070   NaN                NaN                  NaN                     NaN
# 1072   NaN                NaN                  NaN                     NaN
#
#      ball_recovery_recovery_failure block_deflection carry_end_location
# 10                              NaN              NaN                NaN  \
# 11                              NaN              NaN                NaN
# 12                              NaN              NaN                NaN
# 13                              NaN              NaN                NaN
# 14                              NaN              NaN                NaN
# ...                             ...              ...                ...
# 1067                            NaN              NaN                NaN
# 1068                            NaN              NaN                NaN
# 1069                            NaN              NaN                NaN
# 1070                            NaN              NaN                NaN
# 1072                            NaN              NaN                NaN
#
#      clearance_aerial_won clearance_body_part clearance_head  ...
# 10                    NaN                 NaN            NaN  ...  \
# 11                    NaN                 NaN            NaN  ...
# 12                    NaN                 NaN            NaN  ...
# 13                    NaN                 NaN            NaN  ...
# 14                    NaN                 NaN            NaN  ...
# ...                   ...                 ...            ...  ...
# 1067                  NaN                 NaN            NaN  ...
# 1068                  NaN                 NaN            NaN  ...
# 1069                  NaN                 NaN            NaN  ...
# 1070                  NaN                 NaN            NaN  ...
# 1072                  NaN                 NaN            NaN  ...
#
#      substitution_replacement tactics             team team_id     timestamp
# 10                        NaN     NaN  England Women's     865  00:00:00.520  \
# 11                        NaN     NaN  England Women's     865  00:00:03.345
# 12                        NaN     NaN  England Women's     865  00:00:10.646
# 13                        NaN     NaN  England Women's     865  00:00:13.189
# 14                        NaN     NaN  England Women's     865  00:00:15.803
# ...                       ...     ...              ...     ...           ...
# 1067                      NaN     NaN  England Women's     865  00:15:07.083
# 1068                      NaN     NaN  England Women's     865  00:15:07.927
# 1069                      NaN     NaN  England Women's     865  00:15:41.172
# 1070                      NaN     NaN  England Women's     865  00:16:17.561
# 1072                      NaN     NaN  England Women's     865  00:16:26.409
#
#       type under_pressure                            event_uuid
# 10    Pass            NaN  1d9a238d-785b-4b18-8f5f-c2044ee5a359  \
# 11    Pass            NaN  c8417bb6-b907-4b0d-aedf-34f20609616a
# 12    Pass            NaN  ac5d85b6-0638-43d0-bf18-0a9788da9796
# 13    Pass            NaN  499127b0-bf54-4be1-b7b4-51e3cf62c67a
# 14    Pass            NaN  74ca4179-4401-4084-93ec-8164f159883f
# ...    ...            ...                                   ...
# 1067  Pass            NaN  0f246990-4f8b-4a22-b34e-12649400487c
# 1068  Pass            NaN  2e20b19f-0102-4f1b-bd19-6fe857f83c5a
# 1069  Pass            NaN                                   NaN
# 1070  Pass            NaN                                   NaN
# 1072  Pass            NaN  4b5a71a6-ba80-493d-aeaa-76c476ff6edb
#
#                                            visible_area
# 10    [28.1765993115101, 80.0, 48.5861535161855, 0.0...  \
# 11    [17.0745652236595, 80.0, 43.5283105658805, 8.7...
# 12    [102.612049809481, 80.0, 76.1108139381317, 3.9...
# 13    [120.0, 80.0, 73.062961398288, 80.0, 66.128330...
# 14    [57.4037382929914, 80.0, 59.4763383938113, 0.6...
# ...                                                 ...
# 1067  [120.0, 80.0, 92.1641130093236, 80.0, 120.0, 3...
# 1068  [120.0, 80.0, 92.367633026821, 80.0, 120.0, 34...
# 1069                                                NaN
# 1070                                                NaN
# 1072  [55.9457902588158, 79.8391689916615, 46.783632...
#
#                                            freeze_frame
# 10    [{'teammate': True, 'actor': False, 'keeper': ...
# 11    [{'teammate': True, 'actor': True, 'keeper': F...
# 12    [{'teammate': True, 'actor': False, 'keeper': ...
# 13    [{'teammate': True, 'actor': False, 'keeper': ...
# 14    [{'teammate': False, 'actor': False, 'keeper':...
# ...                                                 ...
# 1067  [{'teammate': False, 'actor': False, 'keeper':...
# 1068  [{'teammate': False, 'actor': False, 'keeper':...
# 1069                                                NaN
# 1070                                                NaN
# 1072  [{'teammate': True, 'actor': False, 'keeper': ...
#
# [803 rows x 97 columns]

# %%
# remove any incomplete passes or those which go out etc

passes_df = passes_df[passes_df["pass_outcome"].isna()]

# %%
# make function to select all matches played by given team

def get_pass_data(competition_ID, season_ID, team, data_path):
    """
    get all pass info (event data plus 360 data) for specified competition and season, for specified HOME team only
    :param competition_ID: int, id number of competition
    :param season_ID: int, id number of season
    :param team: str, required team name
    :param data_path: str, path to 360 data
    :return: dict, dictionary of pd dataframes with all pass data for team from season and competition
    """

    matches_df = sb.matches(competition_id=competition_ID, season_id=season_ID)

    match_ids = np.concatenate([np.array(matches_df[matches_df["home_team"]==team]["match_id"]), np.array(matches_df[matches_df["away_team"]==team]["match_id"])])

    all_passes = {}
    for matchid in match_ids:
        # get events
        events = sb.events(match_id=matchid)
        # get 360 data
        threesixty = pd.read_json(f"{data_path}/{matchid}.json")

        df = pd.merge(left=events, right=threesixty, left_on='id', right_on='event_uuid', how='left')

        # filter for passes (complete)
        passes_df = df.dropna(subset=["pass_recipient"])
        passes_df = passes_df[passes_df["pass_outcome"].isna()]

        # get passes between team only (i.e. remove opposition's passes)
        passes_df = passes_df[passes_df["team"]==team]

        # store in dict
        all_passes[str(matchid)] = passes_df
    return all_passes

# %%
def get_one_twos(match, sec=5, prog_threshold=0.75, carry_threshold=5):

    # convert timestamp into seconds
    match["time_in_secs"] = match["minute"]*60 + match["second"]

    # empty list to store index of one-two passes
    one_two_idx = []

    # loop through each pass ...
    for i in range(len(match)):
        player1 = match["player"].iloc[i]
        player2 = match["pass_recipient"].iloc[i]

        # check passes in next n seconds only
        pass_time_sec = match["time_in_secs"].iloc[i]
        cutoff = pass_time_sec + sec
        next_passes_df = match[match["time_in_secs"].between(pass_time_sec, cutoff, inclusive="both")]

        # for every pass that happens in the next n seconds ...
        for j in range(len(next_passes_df)):
            # ... select those where player 2 passes back to player 1 ...
            if next_passes_df["player"].iloc[j] == player2 and next_passes_df["pass_recipient"].iloc[j] == player1:
                # ... then calculate change in distance to goal line to see if the pass combo progresses up the pitch ...
                line_dist_start = 120 - match["location"].iloc[i][0]
                line_dist_end = 120 - next_passes_df["pass_end_location"].iloc[j][0]

                # ... and calculate distance between end of pass 1 and start of pass 2 to see if player 2 is moving
                pass_dist = np.sqrt(np.power(match["pass_end_location"].iloc[i][0]-next_passes_df["location"].iloc[j][0],2) + np.power(match["pass_end_location"].iloc[i][1]-next_passes_df["location"].iloc[j][1],2))

                # store only the passes that satisfy the specified conditions
                if line_dist_end < line_dist_start*prog_threshold and pass_dist < carry_threshold:
                    one_two_idx.append([match.index[i], next_passes_df.index[j]])

    # select the one-twos from the original pass dataframe
    all_onetwos = match.loc[np.array(one_two_idx).reshape(1,-1)[0]]

    # make extra location columns for easier plotting
    all_onetwos[["x_start", "y_start"]] = pd.DataFrame(all_onetwos.location.tolist(), index=all_onetwos.index)
    all_onetwos[["x_end", "y_end"]] = pd.DataFrame(all_onetwos.pass_end_location.tolist(), index=all_onetwos.index)

    return all_onetwos

# %%
get_one_twos(match=euros_eng_passes["3847567"])
# Out:
#      50_50 bad_behaviour_card ball_receipt_outcome ball_recovery_offensive
# 330    NaN                NaN                  NaN                     NaN  \
# 331    NaN                NaN                  NaN                     NaN
# 1016   NaN                NaN                  NaN                     NaN
# 1017   NaN                NaN                  NaN                     NaN
# 1053   NaN                NaN                  NaN                     NaN
# 1054   NaN                NaN                  NaN                     NaN
#
#      ball_recovery_recovery_failure block_deflection carry_end_location
# 330                             NaN              NaN                NaN  \
# 331                             NaN              NaN                NaN
# 1016                            NaN              NaN                NaN
# 1017                            NaN              NaN                NaN
# 1053                            NaN              NaN                NaN
# 1054                            NaN              NaN                NaN
#
#      clearance_aerial_won clearance_body_part clearance_head  ...  type
# 330                   NaN                 NaN            NaN  ...  Pass  \
# 331                   NaN                 NaN            NaN  ...  Pass
# 1016                  NaN                 NaN            NaN  ...  Pass
# 1017                  NaN                 NaN            NaN  ...  Pass
# 1053                  NaN                 NaN            NaN  ...  Pass
# 1054                  NaN                 NaN            NaN  ...  Pass
#
#      under_pressure                            event_uuid
# 330             NaN  1c2e25bf-c189-405e-8496-f590756f9ca0  \
# 331             NaN  4cc7b350-24a4-40bf-891f-c97a5ace978a
# 1016            NaN                                   NaN
# 1017            NaN  2c3cfd2e-060d-47f8-8d10-609ba034fbb1
# 1053            NaN  c8aedfa0-a096-438f-b59e-71d428da7641
# 1054            NaN  2b459bbf-ba39-48b7-99a4-766d8dc45037
#
#                                            visible_area
# 330   [75.3467286928608, 80.0, 69.0391487099963, 23....  \
# 331   [105.065926544272, 80.0, 84.7598449005541, 18....
# 1016                                                NaN
# 1017  [75.0923418150538, 80.0, 58.3526430959521, 80....
# 1053  [87.392487259091, 75.4688639860096, 70.0438837...
# 1054  [88.7055692027562, 73.8431932384068, 71.188189...
#
#                                            freeze_frame time_in_secs x_start
# 330   [{'teammate': True, 'actor': False, 'keeper': ...         2270    91.0  \
# 331   [{'teammate': True, 'actor': False, 'keeper': ...         2274   116.3
# 1016                                                NaN         6505    61.2
# 1017  [{'teammate': True, 'actor': False, 'keeper': ...         6507    70.8
# 1053  [{'teammate': False, 'actor': False, 'keeper':...         6958    94.1
# 1054  [{'teammate': False, 'actor': False, 'keeper':...         6960    91.8
#
#      y_start  x_end  y_end
# 330     71.7  116.3   66.3
# 331     66.3  105.6   46.4
# 1016    74.8   70.8   76.3
# 1017    76.3   89.9   73.9
# 1053    44.7   92.0   41.3
# 1054    41.9  104.4   50.2
#
# [6 rows x 102 columns]

# %%
euros_eng_passes = get_pass_data(competition_ID=53, season_ID=106, team="England Women\'s", data_path="/home/s2113337/Documents/GitHub/open-data/data/three-sixty")

# %%
test_match = euros_eng_passes["3847567"]

# make new time column that is in seconds

test_match["time_in_secs"] = test_match["minute"]*60 + test_match["second"]

# %%
test_match["team"].unique()
# Out:
# array(["England Women's"], dtype=object)

# %%
# join together to get one-two passes ?
# i.e. want passes where the player-recipient combo then becomes recipient-player

one_two_idx = []

for i in range(len(test_match)):
    player1 = test_match["player"].iloc[i]
    player2 = test_match["pass_recipient"].iloc[i]

    # check next 5 seconds
    pass_time_sec = test_match["time_in_secs"].iloc[i]
    cutoff = pass_time_sec + 5
    next_5_df = test_match[test_match["time_in_secs"].between(pass_time_sec, cutoff, inclusive="both")]
    for j in range(len(next_5_df)):
        # get only the one-two passes ...
        if next_5_df["player"].iloc[j] == player2 and next_5_df["pass_recipient"].iloc[j] == player1:
            start_loc = test_match["location"].iloc[i]
            end_loc = next_5_df["pass_end_location"].iloc[j]

            # calculate change in distance to goal line
            line_dist_start = 120 - test_match["location"].iloc[i][0]
            line_dist_end = 120 - next_5_df["pass_end_location"].iloc[j][0]

            # calculate distance between end of pass 1 and start of pass 2
            pass_dist = np.sqrt(np.power(test_match["pass_end_location"].iloc[i][0]-next_5_df["location"].iloc[j][0],2) + np.power(test_match["pass_end_location"].iloc[i][1]-next_5_df["location"].iloc[j][1],2))

            if line_dist_end < line_dist_start*0.8 and pass_dist < 5:
                one_two_idx.append([test_match.index[i], next_5_df.index[j]])
            # # or if the distance between the goal itself is reduced
            # elif

# %%
onetwos = np.array(one_two_idx).reshape(1,-1)

# %%
all_onetwos = test_match.loc[onetwos[0]]

# %%
# plot them ?

all_onetwos[["x_start", "y_start"]] = pd.DataFrame(all_onetwos.location.tolist(), index=all_onetwos.index)
all_onetwos[["x_end", "y_end"]] = pd.DataFrame(all_onetwos.pass_end_location.tolist(), index=all_onetwos.index)

# %%
p = Pitch(pitch_type='statsbomb')

fig, ax = p.draw(figsize=(12,8))

ax.set_title("Visualising England\'s One-Two Passes from Women\'s Euro Final")

for i in range(len(all_onetwos)):
    if i % 2:
        color="blue"
        #p.scatter(x=all_onetwos['x_start'].iloc[i], y=all_onetwos['y_start'].iloc[i], ax=ax, c=color, s=100)
    else:
        color="red"

    # p.scatter(x=all_onetwos['x_start'].iloc[1], y=all_onetwos['y_start'].iloc[1], ax=ax, c="blue", s=100)
    p.arrows(xstart=all_onetwos["x_start"].iloc[i], ystart=all_onetwos["y_start"].iloc[i], xend=all_onetwos["x_end"].iloc[i], yend=all_onetwos["y_end"].iloc[i], ax=ax, width=2, headwidth=5, headlength=5, color=color)
    # p.arrows(xstart=temp["x_start"].iloc[1], ystart=temp["y_start"].iloc[1], xend=temp["x_end"].iloc[1], yend=temp["y_end"].iloc[1], ax=ax, width=2, headwidth=5, headlength=5, color="blue")


# for x in temp.iloc[0]["freeze_frame"]:
#     if x["teammate"]:
#         color="blue"
#     else:
#         color="red"
#     p.scatter(x=x["location"][0], y=x["location"][1], ax=ax, c=color, s=100)
